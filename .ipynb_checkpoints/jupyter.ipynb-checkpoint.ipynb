# %%
import numpy as np
import pandas as pd

# %%
data = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/refs/heads/master/chapter-02-car-price/data.csv"

# %%
df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.columns= df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.dtypes.index
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.dtypes[df.dtypes=='object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
strings =  list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for co in strings:
    df[co]= df[co].str.lower().str.replace(' ', '_')

# %%
df.head(2)
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
# year
# [2011 2012 2013 1992 1993]
# 28
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
# number_of_doors
# [ 2.  4.  3. nan]
# 3
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
# highway_mpg
# [26 28 27 25 24]
# 59
# city_mpg
# [19 20 18 17 16]
# 69
# popularity
# [3916 3105  819  617 1013]
# 48
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.hist( df.msrp[df.msrp< 100000] , bins=50 , edgecolor='black' )
plt.show()

# %%
np.log([1,2,300,2000000])
# Out:
# array([ 0.        ,  0.69314718,  5.70378247, 14.50865774])

# %%
prices = np.log1p(df.msrp)
prices
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
plt.hist( prices , bins=50 , edgecolor='black' )
plt.show()

# %%
df.isnull()
# Out:
#         make  model   year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        transmission_type  driven_wheels  number_of_doors  market_category  \
# 0                  False          False            False            False
# 1                  False          False            False            False
# 2                  False          False            False            False
# 3                  False          False            False            False
# 4                  False          False            False            False
# ...                  ...            ...              ...              ...
# 11909              False          False            False            False
# 11910              False          False            False            False
# 11911              False          False            False            False
# 11912              False          False            False            False
# 11913              False          False            False            False
#
#        vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 0             False          False        False     False       False  False
# 1             False          False        False     False       False  False
# 2             False          False        False     False       False  False
# 3             False          False        False     False       False  False
# 4             False          False        False     False       False  False
# ...             ...            ...          ...       ...         ...    ...
# 11909         False          False        False     False       False  False
# 11910         False          False        False     False       False  False
# 11911         False          False        False     False       False  False
# 11912         False          False        False     False       False  False
# 11913         False          False        False     False       False  False
#
# [11914 rows x 16 columns]

# %%
len(df)
# Out:
# 11914

# %%
df.isnull()[ : 5]
# Out:
#     make  model   year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  False  False  False             False      False             False
# 1  False  False  False             False      False             False
# 2  False  False  False             False      False             False
# 3  False  False  False             False      False             False
# 4  False  False  False             False      False             False
#
#    transmission_type  driven_wheels  number_of_doors  market_category  \
# 0              False          False            False            False
# 1              False          False            False            False
# 2              False          False            False            False
# 3              False          False            False            False
# 4              False          False            False            False
#
#    vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 0         False          False        False     False       False  False
# 1         False          False        False     False       False  False
# 2         False          False        False     False       False  False
# 3         False          False        False     False       False  False
# 4         False          False        False     False       False  False

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
df[ 
df['number_of_doors'].isnull() 
].index.values[ :5]
# Out:
# array([4666, 6930, 6931, 6932, 6933], dtype=int64)

# %%
n = len(df)
n_train= int(n*0.6)
n_val= int(n*0.2)
n_test= int(n*0.2)

# %%
n , n_train, n_test, n_val
# Out:
# (11914, 7148, 2382, 2382)

# %%
df.iloc[[0,1,2]].head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350

# %%
df.iloc[ : 10] # gives a range till 0 to 9
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
# 5               6.0            manual  rear_wheel_drive              2.0
# 6               6.0            manual  rear_wheel_drive              2.0
# 7               6.0            manual  rear_wheel_drive              2.0
# 8               6.0            manual  rear_wheel_drive              2.0
# 9               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
# 5                     luxury,performance      compact         coupe
# 6                     luxury,performance      compact   convertible
# 7                luxury,high-performance      compact         coupe
# 8                                 luxury      compact   convertible
# 9                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500
# 5           28        18        3916  31200
# 6           26        17        3916  44100
# 7           28        20        3916  39300
# 8           28        18        3916  36900
# 9           27        18        3916  37200

# %%
idx = np.arange(n)
np.random.seed(2)
np.random.shuffle(idx)
dftrain = df.iloc[ idx[ :n_train ] ]
dftest = df.iloc[ idx[ n_train : n_train+ n_test] ]
dfval = df.iloc[ idx [ n_train+ n_test  : ]]

# %%
dftrain.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
len(dfval)
# Out:
# 2384

# %%
print(df.iloc[idx[:n_train]].columns)
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
dftest.columns ,dftest.shape
# Out:
# (Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#         'engine_cylinders', 'transmission_type', 'driven_wheels',
#         'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#         'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#        dtype='object'),
#  (2382, 16))

# %%
print("dftest shape:", dftest.shape)
print("dftest columns:", dftest.columns)

dftrain = dftrain.reset_index(drop=True)
dfval = dfval.reset_index(drop=True)
dftest = dftest.reset_index(drop=True)
# Out:
# dftest shape: (2382, 16)
# dftest columns: Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
dftest['msrp'].values
# Out:
# array([303300,  37820,  26885, ...,  35750, 145740,  74425], dtype=int64)

# %%
dftrain.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# 0             NaN      compact              coupe           33        24
# 1       hatchback      compact      4dr_hatchback           32        25
# 2       hatchback      compact      4dr_hatchback           37        28
# 3             NaN        large  passenger_minivan           18        16
# 4       flex_fuel        large    crew_cab_pickup           21        15
#
#    popularity   msrp
# 0        1385  14410
# 1        2031  19685
# 2         640  19795
# 3         873   2000
# 4        5657  56260

# %%
dftrain.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
ytrain= dftrain['msrp'].values
ytest= dftest['msrp'].values
yval= dfval['msrp'].values

# %%
ytrain = np.log1p(dftrain.msrp.values)
yval = np.log1p(dfval.msrp.values)
ytest = np.log1p(dftest.msrp.values)

# %%
del dftest['msrp']
del dftrain['msrp']

del dfval['msrp']

# %%
dftrain.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg',
        'city_mpg', 'popularity']

# %%
xtrain = dftrain[ base].fillna(0).values
xval = dfval[ base].fillna(0).values
xtest= dftest[ base].fillna(0).values

# %% [markdown]
# # scikit learn buitin function for linear regression

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# import matplotlib.pyplot as plt
# import numpy as np

# # === STEP 1: Scale Features ===
# x_scaler = StandardScaler()
# xtrain_scaled = x_scaler.fit_transform(xtrain)

# # === STEP 2: Fit Model ===
# model = LinearRegression()
# model.fit(xtrain_scaled, ytrain)

# # === STEP 3: Predict ===
# y_pred = model.predict(xtrain_scaled)

# # === STEP 4: Evaluation ===
# rmse = np.sqrt(mean_squared_error(ytrain, y_pred))
# mae = mean_absolute_error(ytrain, y_pred)
# r2 = r2_score(ytrain, y_pred)

# print(f"RMSE: {rmse:.4f}")
# print(f"MAE: {mae:.4f}")
# print(f"R² Score: {r2:.4f}")
# print("ytrain[:5]:", ytrain[:5])
# print("y_pred[:5]:", y_pred[:5])

# # === STEP 5: Plot Predictions vs Actual ===
# plt.hist(ytrain, bins=50, alpha=0.5, label="Actual", color="gray")
# plt.hist(y_pred, bins=50, alpha=0.5, label="Predicted", color="red")
# plt.legend()
# plt.xlabel("Log(Price + 1)")
# plt.ylabel("Frequency")
# plt.title("Predictions vs Actual")
# plt.grid(True)
# plt.show()

# %% [markdown]
# # custom functions for gradient descent

# %%
def predicted_value ( X , w , b ):  # f = w.x+ b
    return np.dot(X, w) + b

# %%
def cost_calculator ( xtrain , ytrain , w, b , lambda_):
    m= xtrain.shape[0]
    cost= 0.0
    
    cost =  (1/(2*m))* np.sum((( np.dot(xtrain , w) +b) - ytrain )**2)
    cost= cost+(lambda_ / (2 * m)) * np.sum(w ** 2)
    return cost

# %%
def gradients ( xtrain , ytrain , w, b):
    m= xtrain.shape[0]
    n= xtrain.shape[1] 
    dj_dw = np.zeros(n)
    dj_db=0
    predictions= np.dot(xtrain , w) +b
    error = predictions-ytrain
    dj_dw= (1/m)*np.dot(xtrain.T , error)
    dj_db= (1/m)*np.sum(error)
    return dj_dw , dj_db

# %%
def regression_w_b(xtrain , ytrain ,  iters , alpha , lambda_ , num_indices , cat_indices ):
    j_hist = np.zeros(iters)
    xtrain_scaled = xtrain.copy()
    x_mean = np.mean(xtrain[:, num_indices], axis=0)
    x_std = np.std(xtrain[:, num_indices], axis=0)
    x_std[x_std == 0] = 1 
    xtrain_scaled[:, num_indices] = (xtrain[:, num_indices] - x_mean) / x_std
    m=xtrain_scaled.shape[1]
    w=np.zeros(m)
    b=0.0
    for i in range (iters):
        dj_dw , dj_db = gradients( xtrain_scaled , ytrain , w, b)
        w = w*(1-(lambda_/m)) - alpha * dj_dw
        b = b - alpha * dj_db
        j_hist[i]= cost_calculator(xtrain_scaled , ytrain , w, b , lambda_)
        if i % (iters //10) == 0:
            print(f" {i} iteration cost : {j_hist[i]} ")
    plt.plot(j_hist)
    plt.xlabel("Iteration")
    plt.ylabel("Cost")
    plt.title("Cost vs Iteration")
    plt.grid(True)
    plt.show()
    return j_hist , w, b , x_mean , x_std

# %%
xtrain
# Out:
# array([[ 148.,    4.,   33.,   24., 1385.],
#        [ 132.,    4.,   32.,   25., 2031.],
#        [ 148.,    4.,   37.,   28.,  640.],
#        ...,
#        [ 300.,    6.,   31.,   20., 3916.],
#        [ 210.,    4.,   30.,   24.,  873.],
#        [ 285.,    6.,   22.,   17.,  549.]])

# %%
Scale features
def prepare
    x_mean = np.mean(xtrain, axis=0)
    x_std = np.std(xtrain, axis=0)
    xtrain_scaled = (xtrain - x_mean) / x_std
    
    # Setup
    p = xtrain_scaled.shape[1]
    w = np.zeros(p)
    b = 0.0
    alpha = 1e-2
    iters = 1000
    lambda_=0.0  
    
    # Run training
    
    j_hist, w, b = regression_w_b(xtrain_scaled, ytrain, w, b, iters, alpha , 0)

# %%
y_predict = np.dot(xtrain_scaled , w) + b
len(y_predict)
# Out:
# 7148

# %%
def squared_error(y_true, y_pred):
    m=y_pred.shape[0]
    return (1/(2*m))*(np.sum((y_true - y_pred) ** 2))

# %%
def compare_histogram( ytrain , y_predict ):
    plt.hist(ytrain, bins=50, alpha=0.5, label="Actual", color="gray")
    plt.hist(y_predict, bins=50, alpha=0.5, label="Predicted", color="red")
    plt.legend()
    plt.xlabel("Log(Price + 1)")
    plt.ylabel("Frequency")
    plt.title("Predictions vs Actual")
    plt.grid(True)
    plt.show()
    print(f"squared error : {squared_error(ytrain , y_predict)}")

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
# Out:
# 10.10243668554455

# %%
j_hist, w, b = regression_w_b(xtrain_scaled, ytrain, w, b, iters, alpha , 0)

# Plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 j_hist, w, b = regression_w_b(xtrain_scaled, ytrain, w, b, iters, alpha , 0)
#       3 # Plot
#
# TypeError: regression_w_b() takes 5 positional arguments but 7 were given

# %%
y_pred_4=  np.dot(xtrain_scaled, w)+b
y_pred_4 , ytrain
# Out:
# (array([ 9.54840997,  9.38774618,  9.67259646, ..., 10.59407354,
#         10.10984837, 10.30314944]),
#  array([ 9.57574708,  9.887663  ,  9.89323518, ..., 10.91328684,
#         10.28247178, 10.45380308]))

# %%
compare_histogram(ytrain , y_pred_4_)
# Out:
# squared error : 0.28536061582809985

# %% [markdown]
# # validation of data using dfval

# %%
w_optimal=w 
b_optimal=b

# %%
w_optimal ,b_optimal
# Out:
# (array([ 1.07232117, -0.28300978,  0.13568115,  0.13466423, -0.01288315]),
#  10.10243668554455)

# %%
x_scaled_val= prepare_x(xval)
x_scaled_val
# Out:
# array([[-0.900346  , -0.90256455,  0.78794893,  0.46267707, -0.76935177],
#        [ 0.38263071,  0.21400371, -0.18140319, -0.19503901,  0.12491662],
#        [-0.7467502 ,  0.21400371, -0.71993215, -0.52389705, -0.69065058],
#        ...,
#        [ 0.02122882,  0.21400371, -0.50452057, -0.52389705,  0.21615428],
#        [-0.66543477, -0.90256455,  1.64959526,  1.2300125 ,  0.4606155 ],
#        [ 0.07543911,  0.21400371,  0.03400839,  0.02419968, -0.62727175]])

# %%
y_pred_val= np.dot(x_scaled_val , w_optimal) +b_optimal
y_pred_val
# Out:
# array([ 9.57153874, 10.39968747,  9.08178184, ...,  9.92284679,
#        10.02783497, 10.13872086])

# %%
# Out:
# array([11.02166986, 11.12807263,  8.72561994, ..., 10.08596295,
#        11.01661117, 11.12550986])

# %%
compare_histogram(yval , y_pred_val)
# Out:
# squared error : 0.2705158387146088

# %% [markdown]
# # feature engineering
#
# ### make new feature named age

# %%
def prepare_x( df ):
    df=df.copy()
    features = base.copy()
    df['age']=2017-df.year
    features.append('age')
    df_num=df[features].fillna(0)
    
    
    xnew = df_num.values
    
    return xnew

# %%
x_train_featured = prepare_x(dftrain)
x_train_featured
# Out:
# array([[1.480e+02, 4.000e+00, 3.300e+01, 2.400e+01, 1.385e+03, 9.000e+00],
#        [1.320e+02, 4.000e+00, 3.200e+01, 2.500e+01, 2.031e+03, 5.000e+00],
#        [1.480e+02, 4.000e+00, 3.700e+01, 2.800e+01, 6.400e+02, 1.000e+00],
#        ...,
#        [3.000e+02, 6.000e+00, 3.100e+01, 2.000e+01, 3.916e+03, 2.000e+00],
#        [2.100e+02, 4.000e+00, 3.000e+01, 2.400e+01, 8.730e+02, 2.000e+00],
#        [2.850e+02, 6.000e+00, 2.200e+01, 1.700e+01, 5.490e+02, 2.000e+00]])

# %%
# Scale features
def scale_x ( x , x_mean , x_std , num_indices , cat_indices ):
    x=x.copy()
    
    x[:, num_indices] = (x[:, num_indices] - x_mean) / x_std
    return x

# %%
j_hist , w_featured , b_featured , x_mean ,x_std = regression_w_b(x_train_featured, ytrain ,  3000 , 1e-2 , 0.0)
# Out:
#  0 iteration cost : 50.62379609680939
#  300 iteration cost : 0.2551580206637681
#  600 iteration cost : 0.1344206658486452
#  900 iteration cost : 0.13401014059380326
#  1200 iteration cost : 0.1339623470829766
#  1500 iteration cost : 0.13394225455635447
#  1800 iteration cost : 0.1339335895592941
#  2100 iteration cost : 0.1339298453185938
#  2400 iteration cost : 0.13392822571742113
#  2700 iteration cost : 0.13392752445853864

# %%
#  comapring for training set
x_train_featured_scaled= scale_x(x_train_featured , x_mean , x_std)

y_train_val = np.dot(x_train_featured_scaled , w_featured ) +b_featured 

compare_histogram(  ytrain , y_train_val)
# Out:
# squared error : 0.27844048509383484

# %%
j_hist[1499]
# Out:
# 0.10401048912017392

# %%
x_val_featured = prepare_x(dfval)

x_val_featured_scaled= scale_x(x_val_featured , x_mean , x_std )
# Out:
# array([[ 0.15069588,  0.39325704,  0.92621867,  0.75217873, -0.64895651,
#         -0.98977911],
#        [ 0.72408483,  0.74933953,  0.58894103,  0.44883035,  0.18446153,
#         -0.8410205 ],
#        [ 0.21934103,  0.74933953,  0.40156457,  0.29715616, -0.57561053,
#          2.28291032],
#        ...,
#        [ 0.56256682,  0.74933953,  0.47651515,  0.29715616,  0.26949094,
#          0.497807  ],
#        [ 0.25568259,  0.39325704,  1.22602102,  1.10608516,  0.49731784,
#         -0.98977911],
#        [ 0.58679452,  0.74933953,  0.66389162,  0.54994648, -0.5165443 ,
#         -0.8410205 ]])

# %%
y_pred_val = np.dot(x_val_featured_scaled , w_featured ) +b_featured 
y_pred_val
# Out:
# array([11.02166986, 11.12807263,  8.72561994, ..., 10.08596295,
#        11.01661117, 11.12550986])

# %%
yval
# Out:
# array([ 9.77542688, 10.1924563 ,  7.60140233, ..., 10.27852782,
#        10.00789261, 10.40414162])

# %%
compare_histogram(  yval , y_pred_val)
# Out:
# squared error : 0.28223717509751617

# %%
dftrain.select_dtypes(include='object').dtypes
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %% [markdown]
# # feature all categerical variable

# %%
categorical_variable = [ 'make' ,'model','engine_fuel_type', 'transmission_type' ,  
'driven_wheels'   ,     
'market_category'  ,   
'vehicle_size'   ,      
'vehicle_style' ]
categorical_variable
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
categories ={}
for c in categorical_variable:
    categories[c]=list(df[c].value_counts().head().index)

# %%
categories
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'model': ['silverado_1500',
#   'tundra',
#   'f-150',
#   'sierra_1500',
#   'beetle_convertible'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'luxury,performance',
#   'hatchback'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_x(df):
    df = df.copy()
    features = base.copy()  # Assumes 'base' is a predefined list of base features

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        feature = f'num_doors_{v}'
        df[feature] = (df['number_of_doors'] == v).astype(int)
        features.append(feature)

    for cat, values in categories.items():  # Assumes 'categories' is a list of tuples: (colname, [values])
        for v in values:
            feature_name = f'{cat}_{v}'
            df[feature_name] = (df[cat] == v).astype(int)
            features.append(feature_name)
    
    df_num = df[features].fillna(0)
    xnew = df_num.values

    return  xnew

# %%
x_train_featured= prepare_x(dftrain)
x_train_featured
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [300.,   6.,  31., ...,   0.,   1.,   0.],
#        [210.,   4.,  30., ...,   0.,   0.,   0.],
#        [285.,   6.,  22., ...,   0.,   0.,   0.]])

# %%
num_indices = [0, 1, 2 ,3,4,5]
cat_indices = list(set(range(46)) - set(num_indices))

# %%
df_num.head()
# Out:
#    engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity  age  \
# 0      148.0               4.0           33        24        1385    9
# 1      132.0               4.0           32        25        2031    5
# 2      148.0               4.0           37        28         640    1
# 3       90.0               4.0           18        16         873   26
# 4      385.0               8.0           21        15        5657    0
#
#    num_doors_2  num_doors_3  num_doors_4  make_chevrolet  ...  \
# 0            1            0            0               1  ...
# 1            0            0            1               0  ...
# 2            0            0            1               0  ...
# 3            0            1            0               0  ...
# 4            0            0            1               0  ...
#
#    market_category_luxury,performance  market_category_hatchback  \
# 0                                   0                          0
# 1                                   0                          1
# 2                                   0                          1
# 3                                   0                          0
# 4                                   0                          0
#
#    vehicle_size_compact  vehicle_size_midsize  vehicle_size_large  \
# 0                     1                     0                   0
# 1                     1                     0                   0
# 2                     1                     0                   0
# 3                     0                     0                   1
# 4                     0                     0                   1
#
#    vehicle_style_sedan  vehicle_style_4dr_suv  vehicle_style_coupe  \
# 0                    0                      0                    1
# 1                    0                      0                    0
# 2                    0                      0                    0
# 3                    0                      0                    0
# 4                    0                      0                    0
#
#    vehicle_style_convertible  vehicle_style_4dr_hatchback
# 0                          0                            0
# 1                          0                            1
# 2                          0                            1
# 3                          0                            0
# 4                          0                            0
#
# [5 rows x 46 columns]

# %%
j_hist , w_featured , b_featured , x_mean ,x_std = regression_w_b(x_train_featured, ytrain , 3000 , 1e-2 , 0.0,num_indices, cat_indices)
# Out:
#  0 iteration cost : 48.30216564845157
#  300 iteration cost : 0.3458352545394255
#  600 iteration cost : 0.23750288810426878
#  900 iteration cost : 0.19795020930321441
#  1200 iteration cost : 0.17722309716247667
#  1500 iteration cost : 0.16439159811728368
#  1800 iteration cost : 0.15552384870502026
#  2100 iteration cost : 0.14895783052576617
#  2400 iteration cost : 0.14388457179100508
#  2700 iteration cost : 0.13985513097975005

# %%
x_train_featured_scaled= scale_x(x_train_featured , x_mean , x_std ,num_indices, cat_indices )

y_pred_featured = np.dot(x_train_featured_scaled , w_featured ) +b_featured 

compare_histogram(  ytrain , y_pred_featured)
# Out:
# squared error : 0.13660201819251197

# %%
ytrain , y_pred_featured
# Out:
# (array([ 9.57574708,  9.887663  ,  9.89323518, ..., 10.91328684,
#         10.28247178, 10.45380308]),
#  array([ 9.4261589 ,  9.67359233, 10.36800027, ..., 11.16565964,
#         10.28634826, 10.6631954 ]))

# %%
x_train_featured_scaled[0]
# Out:
# array([  0.15069588,   0.39325704,   0.88874338,   0.75217873,
#         -0.03298009,   0.20028977,   2.0782093 ,  -5.50916302,
#         -0.65587504,   7.59948886,  -3.573883  ,  -3.69425784,
#         -3.84891664,  -4.29846941,  -8.75760539,  -9.11559749,
#         -9.98378968, -10.77869787, -11.35621576,   0.84583069,
#         -2.2420931 ,  -2.60183881,  -3.53006991,  -8.6627105 ,
#         -0.67293798,   2.26476879,  -4.20856768, -13.00732394,
#        -21.80672679,   1.2635783 ,  -1.59110671,  -2.04351644,
#         -2.70221658,  -3.16984439,  -3.5701756 ,  -3.60013021,
#         -4.1570819 ,  -4.13475544,   1.26408544,  -1.31383531,
#         -1.82901305,  -1.71541147,  -1.94290584,   7.02104081,
#         -3.60013021,  -3.95752507])

# %%
def scatter_visu(y_true , y_pred):
    plt.figure(figsize=(8,6))
    plt.scatter(y_true, y_pred, alpha=0.4, color='tomato', edgecolor='k')
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=2, label='Perfect prediction')
    plt.xlabel("Actual Price (Log or Raw)")
    plt.ylabel("Predicted Price")
    plt.title("Actual vs Predicted Prices")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
scatter_visu(ytrain , y_pred_featured)

# %%
def residual_visu(y_true , y_pred):
    residuals = y_true - y_pred

    plt.figure(figsize=(8,5))
    plt.scatter(y_pred, residuals, alpha=0.5, color='mediumblue')
    plt.axhline(0, color='red', linestyle='--')
    plt.xlabel("Predicted Price")
    plt.ylabel("Residual (Actual - Predicted)")
    plt.title("Residual Plot")
    plt.grid(True)
    plt.show()

# %%
residual_visu(ytrain , y_pred_featured)

# %%
sns.histplot(ytrain -y_pred_featured, kde=True)
plt.title("Distribution of Residuals")
plt.xlabel("Residual")
plt.axvline(0, color='red', linestyle='--')
plt.grid(True)
plt.show()

# %% [markdown]
# # validation on featured matrix

# %%
x_val_featured = prepare_x(dfval)

x_val_featured_scaled= scale_x(x_val_featured , x_mean , x_std, num_indices , cat_indices )

# %%
y_pred_val = np.dot(x_val_featured_scaled , w_featured ) +b_featured 
y_pred_val
# Out:
# array([10.01266322, 10.50002669,  7.8203766 , ...,  9.54448254,
#        10.21883363, 10.67032769])

# %%
compare_histogram(  yval , y_pred_val) # this gives quite good results so validation is succesfull
#
# Out:
# squared error : 0.1289065170997538

# %%
scatter_visu(yval , y_pred_val)

# %% [markdown]
# # model tuning

# %%
for i in [0.1 , .01 , 0.001 , 0.0001]: #try deffrent values of alpha
    j_hist , w_featured , b_featured , x_mean ,x_std = regression_w_b(x_train_featured, ytrain , 1000 , i , 0.0,num_indices, cat_indices)
# Out:
#  0 iteration cost : 23.354684841437674
#  100 iteration cost : 0.18875793380261188
#  200 iteration cost : 0.15068142389566686
#  300 iteration cost : 0.13646100096003777
#  400 iteration cost : 0.12916972930300616
#  500 iteration cost : 0.12492665243985665
#  600 iteration cost : 0.12221817971729775
#  700 iteration cost : 0.12034585671327828
#  800 iteration cost : 0.11895857316492445
#  900 iteration cost : 0.11786928684927779
#  0 iteration cost : 48.30216564845157
#  100 iteration cost : 0.8204831731581725
#  200 iteration cost : 0.4566773737804824
#  300 iteration cost : 0.3458352545394255
#  400 iteration cost : 0.29240081148141445
#  500 iteration cost : 0.25994915746081293
#  600 iteration cost : 0.23750288810426878
#  700 iteration cost : 0.22088678539975573
#  800 iteration cost : 0.2080884903171813
#  900 iteration cost : 0.19795020930321441
#  0 iteration cost : 51.31329247282126
#  100 iteration cost : 26.702628616435735
#  200 iteration cost : 14.205053118205818
#  300 iteration cost : 7.824503197710861
#  400 iteration cost : 4.5395578358307835
#  500 iteration cost : 2.825960864254491
#  600 iteration cost : 1.9136008061955174
#  700 iteration cost : 1.4126051800942654
#  800 iteration cost : 1.1250435699252395
#  900 iteration cost : 0.9500216252666814
#  0 iteration cost : 51.61956894269491
#  100 iteration cost : 48.32513285196151
#  200 iteration cost : 45.24719755804971
#  300 iteration cost : 42.3714488185694
#  400 iteration cost : 39.684521109301144
#  500 iteration cost : 37.17393465200734
#  600 iteration cost : 34.8280366267875
#  700 iteration cost : 32.63594629065134
#  800 iteration cost : 30.5875037425108
#  900 iteration cost : 28.673222092085034

# %%
# form the above for graphs we can directly say that best value of alpha is 0.001
#so lets calculate the final values of w and b

# %%
j_hist , w_featured , b_featured , x_mean ,x_std = regression_w_b(x_train_featured, ytrain , 1000 , 0.001 , 0.0,num_indices, cat_indices)
# Out:
#  0 iteration cost : 51.31329247282126
#  100 iteration cost : 26.702628616435735
#  200 iteration cost : 14.205053118205818
#  300 iteration cost : 7.824503197710861
#  400 iteration cost : 4.5395578358307835
#  500 iteration cost : 2.825960864254491
#  600 iteration cost : 1.9136008061955174
#  700 iteration cost : 1.4126051800942654
#  800 iteration cost : 1.1250435699252395
#  900 iteration cost : 0.9500216252666814

# %%
y_pred_val = np.dot(x_val_featured_scaled , w_featured ) +b_featured 
y_pred_val
# Out:
# array([ 9.77920616, 11.49526851,  7.41185966, ...,  9.50813692,
#        10.79380997, 10.94398596])

# %%
compare_histogram(  yval , y_pred_val)
# Out:
# squared error : 0.8039368425751718

# %%
scatter_visu(yval , y_pred_val)

# %% [markdown]
# ## further we can concate the ytest and yval to make this more accurate but we are stopped here becuase we will try some new and advnced algorithms like Xgboost and randomfores

# %%
np.expm1( y_pred_val)[:5] , np.expm1( yval)[:5]
# Out:
# (array([17661.62599939, 98248.80144229,  1654.50215201, 22720.38051275,
#         29873.71890202]),
#  array([17595., 26700.,  2000.,  3211., 31120.]))

# %%
thanks
